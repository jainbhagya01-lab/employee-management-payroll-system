# %% [markdown]
# <a href="https://colab.research.google.com/github/jainbhagya01-lab/employee-management-payroll-system/blob/main/1st_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def register_employee(emp_id, name, age, department, basic_salary):
    if age < 18:
        return "Error: Employee must be at least 18 years old"
    if basic_salary <= 0:
        return "Error: Salary must be greater than 0"

    return "Employee registered successfully"
